# %%
import pandas as pd

df = pd.read_excel('cat_data.xlsx', sheet_name='Data')
df = df.drop(columns=['Horodateur', 'Row.names', 'Plus'])
df = df.drop_duplicates()

df['Sexe'] = df['Sexe'].replace('F', 1)
df['Sexe'] = df['Sexe'].replace('M', 2)

df['Age'] = df['Age'].replace('Moinsde1', 1)
df['Age'] = df['Age'].replace('1a2', 2)
df['Age'] = df['Age'].replace('2a10', 3)
df['Age'] = df['Age'].replace('Plusde10', 4)

df['Race'] = df['Race'].replace('BEN', 1)
df['Race'] = df['Race'].replace('SBI', 2)
df['Race'] = df['Race'].replace('BRI', 3)
df['Race'] = df['Race'].replace('CHA', 4)
df['Race'] = df['Race'].replace('EUR', 5)
df['Race'] = df['Race'].replace('MCO', 6)
df['Race'] = df['Race'].replace('PER', 7)
df['Race'] = df['Race'].replace('RAG', 8)
df['Race'] = df['Race'].replace('SPH', 9)
df['Race'] = df['Race'].replace('ORI', 10)
df['Race'] = df['Race'].replace('TUV', 11)
df['Race'] = df['Race'].replace('Autre', 12)
df['Race'] = df['Race'].replace('NR', 13)
df['Race'] = df['Race'].replace('SAV', 14)

df['Nombre'] = df['Nombre'].replace('Plusde5', 6)

df['Logement'] = df['Logement'].replace('ASB', 1)
df['Logement'] = df['Logement'].replace('AAB', 2)
df['Logement'] = df['Logement'].replace('ML', 3)
df['Logement'] = df['Logement'].replace('MI', 4)

df['Zone'] = df['Zone'].replace('U', 1)
df['Zone'] = df['Zone'].replace('PU', 2)
df['Zone'] = df['Zone'].replace('R', 3)

df = df.replace('NSP', 0)

df = df.astype(int)

def inlocuieste_zero_cu_media(df):
    for col in df.columns:
        media_rotunjita = round(df[df[col] != 0][col].mean())
        df[col] = df[col].replace(0, media_rotunjita)
    return df

def numara_instante_rase(df):
    result = {}
    for val in range(1, 15):
        count = int((df['Race'] == val).sum())
        result[val] = count
    return result

def extrage_statistici(df, class_column):
    statistici = {}
    
    # Iterăm prin toate coloanele din dataframe
    for col in df.columns:
        if col != class_column:  # Ignorăm coloana cu clasele pentru prelucrarea generală
            # La nivelul întregului fișier
            valori_distincte = df[col].value_counts().to_dict()
            statistici[col] = {
                'total_valori_distincte': len(valori_distincte),
                'frecventa_valori_total': valori_distincte
            }
            
            # La nivelul fiecărei clase
            statistici[col]['frecventa_pe_clase'] = {}
            for clasa in df[class_column].unique():
                valori_pe_clasa = df[df[class_column] == clasa][col].value_counts().to_dict()
                statistici[col]['frecventa_pe_clase'][clasa] = valori_pe_clasa
    
    return statistici

def afiseaza_statistici(statistici):
    for col, data in statistici.items():
        print(f"\nAtribut: {col}")
        print(f"Număr total de valori distincte: {data['total_valori_distincte']}")
        print("Frecvența valorilor la nivel total:")
        for valoare, frecventa in data['frecventa_valori_total'].items():
            print(f"  Valoare {valoare}: {frecventa} apariții")
        
        print("\nFrecvența valorilor pe clase:")
        for clasa, frecventa_clasa in data['frecventa_pe_clase'].items():
            print(f"  Clasa {clasa}:")
            for valoare, frecventa in frecventa_clasa.items():
                print(f"    Valoare {valoare}: {frecventa} apariții")
        print("-" * 50)


df = inlocuieste_zero_cu_media(df)

distributie_rase = extrage_statistici(df, 'Race')
afiseaza_statistici(distributie_rase)
# Out:
# C:\Users\REBECA\AppData\Local\Temp\ipykernel_8180\1290283863.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Age'] = df['Age'].replace('Plusde10', 4)
# C:\Users\REBECA\AppData\Local\Temp\ipykernel_8180\1290283863.py:35: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Logement'] = df['Logement'].replace('MI', 4)
# C:\Users\REBECA\AppData\Local\Temp\ipykernel_8180\1290283863.py:39: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Zone'] = df['Zone'].replace('R', 3)
# C:\Users\REBECA\AppData\Local\Temp\ipykernel_8180\1290283863.py:41: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace('NSP', 0)
# Atribut: Sexe
# Număr total de valori distincte: 2
# Frecvența valorilor la nivel total:
#   Valoare 2: 1655 apariții
#   Valoare 1: 1484 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 99 apariții
#     Valoare 2: 93 apariții
#   Clasa 5:
#     Valoare 2: 523 apariții
#     Valoare 1: 497 apariții
#   Clasa 13:
#     Valoare 2: 251 apariții
#     Valoare 1: 232 apariții
#   Clasa 6:
#     Valoare 2: 127 apariții
#     Valoare 1: 71 apariții
#   Clasa 1:
#     Valoare 2: 123 apariții
#     Valoare 1: 115 apariții
#   Clasa 7:
#     Valoare 2: 158 apariții
#     Valoare 1: 113 apariții
#   Clasa 10:
#     Valoare 2: 30 apariții
#     Valoare 1: 28 apariții
#   Clasa 3:
#     Valoare 2: 91 apariții
#     Valoare 1: 75 apariții
#   Clasa 12:
#     Valoare 1: 70 apariții
#     Valoare 2: 65 apariții
#   Clasa 4:
#     Valoare 2: 19 apariții
#     Valoare 1: 12 apariții
#   Clasa 8:
#     Valoare 1: 110 apariții
#     Valoare 2: 107 apariții
#   Clasa 11:
#     Valoare 1: 14 apariții
#     Valoare 2: 14 apariții
#   Clasa 9:
#     Valoare 2: 38 apariții
#     Valoare 1: 38 apariții
#   Clasa 14:
#     Valoare 2: 16 apariții
#     Valoare 1: 10 apariții
# --------------------------------------------------
#
# Atribut: Age
# Număr total de valori distincte: 4
# Frecvența valorilor la nivel total:
#   Valoare 3: 1559 apariții
#   Valoare 2: 617 apariții
#   Valoare 1: 607 apariții
#   Valoare 4: 356 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 3: 97 apariții
#     Valoare 1: 46 apariții
#     Valoare 2: 39 apariții
#     Valoare 4: 10 apariții
#   Clasa 5:
#     Valoare 3: 518 apariții
#     Valoare 1: 171 apariții
#     Valoare 4: 171 apariții
#     Valoare 2: 160 apariții
#   Clasa 13:
#     Valoare 3: 253 apariții
#     Valoare 4: 81 apariții
#     Valoare 1: 75 apariții
#     Valoare 2: 74 apariții
#   Clasa 6:
#     Valoare 3: 96 apariții
#     Valoare 2: 56 apariții
#     Valoare 1: 39 apariții
#     Valoare 4: 7 apariții
#   Clasa 1:
#     Valoare 3: 106 apariții
#     Valoare 2: 69 apariții
#     Valoare 1: 57 apariții
#     Valoare 4: 6 apariții
#   Clasa 7:
#     Valoare 3: 138 apariții
#     Valoare 2: 58 apariții
#     Valoare 1: 44 apariții
#     Valoare 4: 31 apariții
#   Clasa 10:
#     Valoare 3: 27 apariții
#     Valoare 4: 13 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 8 apariții
#   Clasa 3:
#     Valoare 3: 78 apariții
#     Valoare 2: 41 apariții
#     Valoare 1: 40 apariții
#     Valoare 4: 7 apariții
#   Clasa 12:
#     Valoare 3: 80 apariții
#     Valoare 1: 27 apariții
#     Valoare 2: 21 apariții
#     Valoare 4: 7 apariții
#   Clasa 4:
#     Valoare 3: 19 apariții
#     Valoare 4: 6 apariții
#     Valoare 1: 3 apariții
#     Valoare 2: 3 apariții
#   Clasa 8:
#     Valoare 3: 98 apariții
#     Valoare 1: 65 apariții
#     Valoare 2: 48 apariții
#     Valoare 4: 6 apariții
#   Clasa 11:
#     Valoare 3: 9 apariții
#     Valoare 4: 7 apariții
#     Valoare 1: 7 apariții
#     Valoare 2: 5 apariții
#   Clasa 9:
#     Valoare 2: 27 apariții
#     Valoare 3: 26 apariții
#     Valoare 1: 19 apariții
#     Valoare 4: 4 apariții
#   Clasa 14:
#     Valoare 3: 14 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 6 apariții
# --------------------------------------------------
#
# Atribut: Nombre
# Număr total de valori distincte: 6
# Frecvența valorilor la nivel total:
#   Valoare 1: 1280 apariții
#   Valoare 2: 972 apariții
#   Valoare 3: 364 apariții
#   Valoare 6: 225 apariții
#   Valoare 4: 202 apariții
#   Valoare 5: 96 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 84 apariții
#     Valoare 2: 60 apariții
#     Valoare 3: 24 apariții
#     Valoare 4: 11 apariții
#     Valoare 6: 8 apariții
#     Valoare 5: 5 apariții
#   Clasa 5:
#     Valoare 1: 396 apariții
#     Valoare 2: 316 apariții
#     Valoare 3: 132 apariții
#     Valoare 4: 80 apariții
#     Valoare 6: 66 apariții
#     Valoare 5: 30 apariții
#   Clasa 13:
#     Valoare 1: 178 apariții
#     Valoare 2: 175 apariții
#     Valoare 3: 56 apariții
#     Valoare 4: 29 apariții
#     Valoare 6: 28 apariții
#     Valoare 5: 17 apariții
#   Clasa 6:
#     Valoare 2: 57 apariții
#     Valoare 1: 47 apariții
#     Valoare 3: 38 apariții
#     Valoare 6: 31 apariții
#     Valoare 4: 15 apariții
#     Valoare 5: 10 apariții
#   Clasa 1:
#     Valoare 1: 111 apariții
#     Valoare 2: 68 apariții
#     Valoare 3: 23 apariții
#     Valoare 6: 14 apariții
#     Valoare 4: 11 apariții
#     Valoare 5: 11 apariții
#   Clasa 7:
#     Valoare 1: 131 apariții
#     Valoare 2: 89 apariții
#     Valoare 4: 17 apariții
#     Valoare 6: 15 apariții
#     Valoare 3: 15 apariții
#     Valoare 5: 4 apariții
#   Clasa 10:
#     Valoare 1: 22 apariții
#     Valoare 2: 19 apariții
#     Valoare 4: 6 apariții
#     Valoare 6: 6 apariții
#     Valoare 3: 3 apariții
#     Valoare 5: 2 apariții
#   Clasa 3:
#     Valoare 1: 89 apariții
#     Valoare 2: 46 apariții
#     Valoare 6: 12 apariții
#     Valoare 3: 11 apariții
#     Valoare 4: 5 apariții
#     Valoare 5: 3 apariții
#   Clasa 12:
#     Valoare 1: 51 apariții
#     Valoare 2: 29 apariții
#     Valoare 3: 27 apariții
#     Valoare 6: 14 apariții
#     Valoare 4: 11 apariții
#     Valoare 5: 3 apariții
#   Clasa 4:
#     Valoare 1: 12 apariții
#     Valoare 2: 12 apariții
#     Valoare 6: 4 apariții
#     Valoare 4: 2 apariții
#     Valoare 3: 1 apariții
#   Clasa 8:
#     Valoare 1: 104 apariții
#     Valoare 2: 72 apariții
#     Valoare 3: 18 apariții
#     Valoare 6: 12 apariții
#     Valoare 4: 6 apariții
#     Valoare 5: 5 apariții
#   Clasa 11:
#     Valoare 1: 11 apariții
#     Valoare 2: 7 apariții
#     Valoare 3: 4 apariții
#     Valoare 6: 2 apariții
#     Valoare 5: 2 apariții
#     Valoare 4: 2 apariții
#   Clasa 9:
#     Valoare 1: 32 apariții
#     Valoare 2: 20 apariții
#     Valoare 6: 10 apariții
#     Valoare 3: 7 apariții
#     Valoare 4: 4 apariții
#     Valoare 5: 3 apariții
#   Clasa 14:
#     Valoare 1: 12 apariții
#     Valoare 3: 5 apariții
#     Valoare 6: 3 apariții
#     Valoare 4: 3 apariții
#     Valoare 2: 2 apariții
#     Valoare 5: 1 apariții
# --------------------------------------------------
#
# Atribut: Logement
# Număr total de valori distincte: 4
# Frecvența valorilor la nivel total:
#   Valoare 4: 998 apariții
#   Valoare 3: 988 apariții
#   Valoare 2: 784 apariții
#   Valoare 1: 369 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 67 apariții
#     Valoare 3: 59 apariții
#     Valoare 2: 48 apariții
#     Valoare 1: 18 apariții
#   Clasa 5:
#     Valoare 3: 333 apariții
#     Valoare 4: 329 apariții
#     Valoare 2: 241 apariții
#     Valoare 1: 117 apariții
#   Clasa 13:
#     Valoare 4: 159 apariții
#     Valoare 3: 152 apariții
#     Valoare 2: 108 apariții
#     Valoare 1: 64 apariții
#   Clasa 6:
#     Valoare 4: 77 apariții
#     Valoare 3: 65 apariții
#     Valoare 2: 40 apariții
#     Valoare 1: 16 apariții
#   Clasa 1:
#     Valoare 2: 76 apariții
#     Valoare 3: 66 apariții
#     Valoare 4: 64 apariții
#     Valoare 1: 32 apariții
#   Clasa 7:
#     Valoare 3: 93 apariții
#     Valoare 4: 92 apariții
#     Valoare 2: 62 apariții
#     Valoare 1: 24 apariții
#   Clasa 10:
#     Valoare 3: 20 apariții
#     Valoare 2: 18 apariții
#     Valoare 4: 14 apariții
#     Valoare 1: 6 apariții
#   Clasa 3:
#     Valoare 3: 53 apariții
#     Valoare 2: 48 apariții
#     Valoare 4: 47 apariții
#     Valoare 1: 18 apariții
#   Clasa 12:
#     Valoare 4: 40 apariții
#     Valoare 3: 39 apariții
#     Valoare 2: 38 apariții
#     Valoare 1: 18 apariții
#   Clasa 4:
#     Valoare 4: 12 apariții
#     Valoare 3: 8 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 5 apariții
#   Clasa 8:
#     Valoare 4: 63 apariții
#     Valoare 3: 62 apariții
#     Valoare 2: 62 apariții
#     Valoare 1: 30 apariții
#   Clasa 11:
#     Valoare 3: 9 apariții
#     Valoare 1: 7 apariții
#     Valoare 2: 7 apariții
#     Valoare 4: 5 apariții
#   Clasa 9:
#     Valoare 3: 22 apariții
#     Valoare 4: 21 apariții
#     Valoare 2: 20 apariții
#     Valoare 1: 13 apariții
#   Clasa 14:
#     Valoare 2: 10 apariții
#     Valoare 4: 8 apariții
#     Valoare 3: 7 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Zone
# Număr total de valori distincte: 3
# Frecvența valorilor la nivel total:
#   Valoare 3: 1224 apariții
#   Valoare 1: 1099 apariții
#   Valoare 2: 816 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 3: 81 apariții
#     Valoare 1: 57 apariții
#     Valoare 2: 54 apariții
#   Clasa 5:
#     Valoare 3: 410 apariții
#     Valoare 1: 341 apariții
#     Valoare 2: 269 apariții
#   Clasa 13:
#     Valoare 3: 196 apariții
#     Valoare 1: 166 apariții
#     Valoare 2: 121 apariții
#   Clasa 6:
#     Valoare 3: 79 apariții
#     Valoare 1: 62 apariții
#     Valoare 2: 57 apariții
#   Clasa 1:
#     Valoare 3: 89 apariții
#     Valoare 1: 87 apariții
#     Valoare 2: 62 apariții
#   Clasa 7:
#     Valoare 3: 105 apariții
#     Valoare 1: 88 apariții
#     Valoare 2: 78 apariții
#   Clasa 10:
#     Valoare 1: 28 apariții
#     Valoare 3: 17 apariții
#     Valoare 2: 13 apariții
#   Clasa 3:
#     Valoare 1: 68 apariții
#     Valoare 3: 54 apariții
#     Valoare 2: 44 apariții
#   Clasa 12:
#     Valoare 3: 61 apariții
#     Valoare 1: 39 apariții
#     Valoare 2: 35 apariții
#   Clasa 4:
#     Valoare 3: 13 apariții
#     Valoare 1: 11 apariții
#     Valoare 2: 7 apariții
#   Clasa 8:
#     Valoare 1: 94 apariții
#     Valoare 3: 75 apariții
#     Valoare 2: 48 apariții
#   Clasa 11:
#     Valoare 1: 17 apariții
#     Valoare 2: 6 apariții
#     Valoare 3: 5 apariții
#   Clasa 9:
#     Valoare 1: 32 apariții
#     Valoare 3: 27 apariții
#     Valoare 2: 17 apariții
#   Clasa 14:
#     Valoare 3: 12 apariții
#     Valoare 1: 9 apariții
#     Valoare 2: 5 apariții
# --------------------------------------------------
#
# Atribut: Ext
# Număr total de valori distincte: 4
# Frecvența valorilor la nivel total:
#   Valoare 2: 2107 apariții
#   Valoare 1: 624 apariții
#   Valoare 3: 374 apariții
#   Valoare 4: 34 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 2: 132 apariții
#     Valoare 1: 55 apariții
#     Valoare 3: 5 apariții
#   Clasa 5:
#     Valoare 2: 623 apariții
#     Valoare 3: 210 apariții
#     Valoare 1: 167 apariții
#     Valoare 4: 20 apariții
#   Clasa 13:
#     Valoare 2: 317 apariții
#     Valoare 1: 82 apariții
#     Valoare 3: 76 apariții
#     Valoare 4: 8 apariții
#   Clasa 6:
#     Valoare 2: 153 apariții
#     Valoare 1: 34 apariții
#     Valoare 3: 10 apariții
#     Valoare 4: 1 apariții
#   Clasa 1:
#     Valoare 2: 166 apariții
#     Valoare 1: 59 apariții
#     Valoare 3: 13 apariții
#   Clasa 7:
#     Valoare 2: 188 apariții
#     Valoare 1: 58 apariții
#     Valoare 3: 24 apariții
#     Valoare 4: 1 apariții
#   Clasa 10:
#     Valoare 2: 42 apariții
#     Valoare 1: 9 apariții
#     Valoare 3: 6 apariții
#     Valoare 4: 1 apariții
#   Clasa 3:
#     Valoare 2: 109 apariții
#     Valoare 1: 46 apariții
#     Valoare 3: 10 apariții
#     Valoare 4: 1 apariții
#   Clasa 12:
#     Valoare 2: 94 apariții
#     Valoare 1: 28 apariții
#     Valoare 3: 12 apariții
#     Valoare 4: 1 apariții
#   Clasa 4:
#     Valoare 2: 21 apariții
#     Valoare 1: 6 apariții
#     Valoare 3: 4 apariții
#   Clasa 8:
#     Valoare 2: 161 apariții
#     Valoare 1: 56 apariții
#   Clasa 11:
#     Valoare 2: 20 apariții
#     Valoare 1: 5 apariții
#     Valoare 3: 3 apariții
#   Clasa 9:
#     Valoare 2: 61 apariții
#     Valoare 1: 14 apariții
#     Valoare 4: 1 apariții
#   Clasa 14:
#     Valoare 2: 20 apariții
#     Valoare 1: 5 apariții
#     Valoare 3: 1 apariții
# --------------------------------------------------
#
# Atribut: Obs
# Număr total de valori distincte: 3
# Frecvența valorilor la nivel total:
#   Valoare 2: 1989 apariții
#   Valoare 3: 827 apariții
#   Valoare 1: 323 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 2: 114 apariții
#     Valoare 3: 66 apariții
#     Valoare 1: 12 apariții
#   Clasa 5:
#     Valoare 2: 637 apariții
#     Valoare 3: 265 apariții
#     Valoare 1: 118 apariții
#   Clasa 13:
#     Valoare 2: 306 apariții
#     Valoare 3: 110 apariții
#     Valoare 1: 67 apariții
#   Clasa 6:
#     Valoare 2: 126 apariții
#     Valoare 3: 61 apariții
#     Valoare 1: 11 apariții
#   Clasa 1:
#     Valoare 2: 164 apariții
#     Valoare 3: 58 apariții
#     Valoare 1: 16 apariții
#   Clasa 7:
#     Valoare 2: 186 apariții
#     Valoare 3: 54 apariții
#     Valoare 1: 31 apariții
#   Clasa 10:
#     Valoare 2: 40 apariții
#     Valoare 3: 12 apariții
#     Valoare 1: 6 apariții
#   Clasa 3:
#     Valoare 2: 103 apariții
#     Valoare 3: 42 apariții
#     Valoare 1: 21 apariții
#   Clasa 12:
#     Valoare 2: 79 apariții
#     Valoare 3: 45 apariții
#     Valoare 1: 11 apariții
#   Clasa 4:
#     Valoare 2: 25 apariții
#     Valoare 3: 4 apariții
#     Valoare 1: 2 apariții
#   Clasa 8:
#     Valoare 2: 131 apariții
#     Valoare 3: 63 apariții
#     Valoare 1: 23 apariții
#   Clasa 11:
#     Valoare 2: 17 apariții
#     Valoare 3: 8 apariții
#     Valoare 1: 3 apariții
#   Clasa 9:
#     Valoare 2: 44 apariții
#     Valoare 3: 31 apariții
#     Valoare 1: 1 apariții
#   Clasa 14:
#     Valoare 2: 17 apariții
#     Valoare 3: 8 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Timide
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1080 apariții
#   Valoare 4: 702 apariții
#   Valoare 2: 647 apariții
#   Valoare 3: 437 apariții
#   Valoare 5: 273 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 79 apariții
#     Valoare 2: 45 apariții
#     Valoare 4: 37 apariții
#     Valoare 3: 25 apariții
#     Valoare 5: 6 apariții
#   Clasa 5:
#     Valoare 1: 283 apariții
#     Valoare 4: 254 apariții
#     Valoare 2: 193 apariții
#     Valoare 3: 148 apariții
#     Valoare 5: 142 apariții
#   Clasa 13:
#     Valoare 1: 141 apariții
#     Valoare 4: 122 apariții
#     Valoare 2: 97 apariții
#     Valoare 3: 78 apariții
#     Valoare 5: 45 apariții
#   Clasa 6:
#     Valoare 1: 91 apariții
#     Valoare 4: 44 apariții
#     Valoare 2: 35 apariții
#     Valoare 3: 22 apariții
#     Valoare 5: 6 apariții
#   Clasa 1:
#     Valoare 1: 106 apariții
#     Valoare 2: 60 apariții
#     Valoare 4: 42 apariții
#     Valoare 3: 23 apariții
#     Valoare 5: 7 apariții
#   Clasa 7:
#     Valoare 1: 75 apariții
#     Valoare 4: 70 apariții
#     Valoare 2: 64 apariții
#     Valoare 3: 41 apariții
#     Valoare 5: 21 apariții
#   Clasa 10:
#     Valoare 1: 19 apariții
#     Valoare 4: 12 apariții
#     Valoare 3: 9 apariții
#     Valoare 5: 9 apariții
#     Valoare 2: 9 apariții
#   Clasa 3:
#     Valoare 1: 53 apariții
#     Valoare 4: 49 apariții
#     Valoare 2: 37 apariții
#     Valoare 3: 20 apariții
#     Valoare 5: 7 apariții
#   Clasa 12:
#     Valoare 1: 51 apariții
#     Valoare 2: 29 apariții
#     Valoare 4: 23 apariții
#     Valoare 3: 20 apariții
#     Valoare 5: 12 apariții
#   Clasa 4:
#     Valoare 1: 15 apariții
#     Valoare 4: 5 apariții
#     Valoare 2: 5 apariții
#     Valoare 3: 4 apariții
#     Valoare 5: 2 apariții
#   Clasa 8:
#     Valoare 1: 99 apariții
#     Valoare 2: 46 apariții
#     Valoare 3: 31 apariții
#     Valoare 4: 29 apariții
#     Valoare 5: 12 apariții
#   Clasa 11:
#     Valoare 1: 10 apariții
#     Valoare 4: 7 apariții
#     Valoare 2: 5 apariții
#     Valoare 3: 4 apariții
#     Valoare 5: 2 apariții
#   Clasa 9:
#     Valoare 1: 52 apariții
#     Valoare 2: 16 apariții
#     Valoare 3: 5 apariții
#     Valoare 4: 2 apariții
#     Valoare 5: 1 apariții
#   Clasa 14:
#     Valoare 3: 7 apariții
#     Valoare 2: 6 apariții
#     Valoare 4: 6 apariții
#     Valoare 1: 6 apariții
#     Valoare 5: 1 apariții
# --------------------------------------------------
#
# Atribut: Calme
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 1172 apariții
#   Valoare 5: 677 apariții
#   Valoare 2: 542 apariții
#   Valoare 3: 528 apariții
#   Valoare 1: 220 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 85 apariții
#     Valoare 5: 44 apariții
#     Valoare 3: 29 apariții
#     Valoare 2: 25 apariții
#     Valoare 1: 9 apariții
#   Clasa 5:
#     Valoare 4: 375 apariții
#     Valoare 5: 210 apariții
#     Valoare 2: 180 apariții
#     Valoare 3: 180 apariții
#     Valoare 1: 75 apariții
#   Clasa 13:
#     Valoare 4: 188 apariții
#     Valoare 5: 97 apariții
#     Valoare 3: 91 apariții
#     Valoare 2: 81 apariții
#     Valoare 1: 26 apariții
#   Clasa 6:
#     Valoare 4: 81 apariții
#     Valoare 2: 40 apariții
#     Valoare 5: 37 apariții
#     Valoare 3: 26 apariții
#     Valoare 1: 14 apariții
#   Clasa 1:
#     Valoare 2: 73 apariții
#     Valoare 4: 54 apariții
#     Valoare 1: 52 apariții
#     Valoare 3: 46 apariții
#     Valoare 5: 13 apariții
#   Clasa 7:
#     Valoare 4: 105 apariții
#     Valoare 5: 80 apariții
#     Valoare 3: 38 apariții
#     Valoare 2: 37 apariții
#     Valoare 1: 11 apariții
#   Clasa 10:
#     Valoare 4: 26 apariții
#     Valoare 2: 17 apariții
#     Valoare 5: 7 apariții
#     Valoare 3: 5 apariții
#     Valoare 1: 3 apariții
#   Clasa 3:
#     Valoare 4: 69 apariții
#     Valoare 5: 52 apariții
#     Valoare 3: 24 apariții
#     Valoare 2: 18 apariții
#     Valoare 1: 3 apariții
#   Clasa 12:
#     Valoare 4: 51 apariții
#     Valoare 5: 32 apariții
#     Valoare 3: 25 apariții
#     Valoare 2: 24 apariții
#     Valoare 1: 3 apariții
#   Clasa 4:
#     Valoare 4: 13 apariții
#     Valoare 5: 10 apariții
#     Valoare 3: 4 apariții
#     Valoare 2: 3 apariții
#     Valoare 1: 1 apariții
#   Clasa 8:
#     Valoare 4: 90 apariții
#     Valoare 5: 77 apariții
#     Valoare 3: 28 apariții
#     Valoare 2: 18 apariții
#     Valoare 1: 4 apariții
#   Clasa 11:
#     Valoare 4: 16 apariții
#     Valoare 5: 4 apariții
#     Valoare 3: 4 apariții
#     Valoare 2: 2 apariții
#     Valoare 1: 2 apariții
#   Clasa 9:
#     Valoare 3: 22 apariții
#     Valoare 2: 18 apariții
#     Valoare 4: 16 apariții
#     Valoare 5: 12 apariții
#     Valoare 1: 8 apariții
#   Clasa 14:
#     Valoare 1: 9 apariții
#     Valoare 3: 6 apariții
#     Valoare 2: 6 apariții
#     Valoare 4: 3 apariții
#     Valoare 5: 2 apariții
# --------------------------------------------------
#
# Atribut: Effrayé
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1003 apariții
#   Valoare 3: 814 apariții
#   Valoare 2: 678 apariții
#   Valoare 4: 439 apariții
#   Valoare 5: 205 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 56 apariții
#     Valoare 2: 55 apariții
#     Valoare 3: 52 apariții
#     Valoare 4: 20 apariții
#     Valoare 5: 9 apariții
#   Clasa 5:
#     Valoare 1: 274 apariții
#     Valoare 3: 263 apariții
#     Valoare 2: 212 apariții
#     Valoare 4: 178 apariții
#     Valoare 5: 93 apariții
#   Clasa 13:
#     Valoare 1: 150 apariții
#     Valoare 3: 116 apariții
#     Valoare 2: 103 apariții
#     Valoare 4: 79 apariții
#     Valoare 5: 35 apariții
#   Clasa 6:
#     Valoare 1: 97 apariții
#     Valoare 2: 49 apariții
#     Valoare 3: 32 apariții
#     Valoare 4: 16 apariții
#     Valoare 5: 4 apariții
#   Clasa 1:
#     Valoare 1: 93 apariții
#     Valoare 3: 66 apariții
#     Valoare 2: 54 apariții
#     Valoare 4: 17 apariții
#     Valoare 5: 8 apariții
#   Clasa 7:
#     Valoare 3: 83 apariții
#     Valoare 1: 71 apariții
#     Valoare 2: 65 apariții
#     Valoare 4: 32 apariții
#     Valoare 5: 20 apariții
#   Clasa 10:
#     Valoare 1: 15 apariții
#     Valoare 2: 14 apariții
#     Valoare 3: 13 apariții
#     Valoare 4: 10 apariții
#     Valoare 5: 6 apariții
#   Clasa 3:
#     Valoare 3: 53 apariții
#     Valoare 1: 45 apariții
#     Valoare 2: 32 apariții
#     Valoare 4: 29 apariții
#     Valoare 5: 7 apariții
#   Clasa 12:
#     Valoare 1: 60 apariții
#     Valoare 2: 28 apariții
#     Valoare 3: 24 apariții
#     Valoare 4: 16 apariții
#     Valoare 5: 7 apariții
#   Clasa 4:
#     Valoare 1: 10 apariții
#     Valoare 2: 8 apariții
#     Valoare 4: 6 apariții
#     Valoare 3: 5 apariții
#     Valoare 5: 2 apariții
#   Clasa 8:
#     Valoare 3: 75 apariții
#     Valoare 1: 67 apariții
#     Valoare 2: 41 apariții
#     Valoare 4: 26 apariții
#     Valoare 5: 8 apariții
#   Clasa 11:
#     Valoare 1: 9 apariții
#     Valoare 2: 8 apariții
#     Valoare 4: 4 apariții
#     Valoare 5: 4 apariții
#     Valoare 3: 3 apariții
#   Clasa 9:
#     Valoare 1: 42 apariții
#     Valoare 3: 20 apariții
#     Valoare 2: 8 apariții
#     Valoare 4: 5 apariții
#     Valoare 5: 1 apariții
#   Clasa 14:
#     Valoare 1: 14 apariții
#     Valoare 3: 9 apariții
#     Valoare 2: 1 apariții
#     Valoare 4: 1 apariții
#     Valoare 5: 1 apariții
# --------------------------------------------------
#
# Atribut: Intelligent
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 5: 1327 apariții
#   Valoare 4: 1263 apariții
#   Valoare 3: 350 apariții
#   Valoare 2: 136 apariții
#   Valoare 1: 63 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 5: 83 apariții
#     Valoare 4: 77 apariții
#     Valoare 3: 23 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 3 apariții
#   Clasa 5:
#     Valoare 5: 418 apariții
#     Valoare 4: 415 apariții
#     Valoare 3: 118 apariții
#     Valoare 2: 47 apariții
#     Valoare 1: 22 apariții
#   Clasa 13:
#     Valoare 4: 202 apariții
#     Valoare 5: 186 apariții
#     Valoare 3: 53 apariții
#     Valoare 2: 29 apariții
#     Valoare 1: 13 apariții
#   Clasa 6:
#     Valoare 5: 96 apariții
#     Valoare 4: 71 apariții
#     Valoare 3: 19 apariții
#     Valoare 2: 9 apariții
#     Valoare 1: 3 apariții
#   Clasa 1:
#     Valoare 5: 131 apariții
#     Valoare 4: 82 apariții
#     Valoare 3: 13 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 2 apariții
#   Clasa 7:
#     Valoare 4: 117 apariții
#     Valoare 5: 98 apariții
#     Valoare 3: 41 apariții
#     Valoare 2: 11 apariții
#     Valoare 1: 4 apariții
#   Clasa 10:
#     Valoare 5: 30 apariții
#     Valoare 4: 18 apariții
#     Valoare 3: 7 apariții
#     Valoare 2: 3 apariții
#   Clasa 3:
#     Valoare 4: 70 apariții
#     Valoare 5: 64 apariții
#     Valoare 3: 25 apariții
#     Valoare 1: 4 apariții
#     Valoare 2: 3 apariții
#   Clasa 12:
#     Valoare 5: 66 apariții
#     Valoare 4: 57 apariții
#     Valoare 3: 7 apariții
#     Valoare 2: 3 apariții
#     Valoare 1: 2 apariții
#   Clasa 4:
#     Valoare 4: 17 apariții
#     Valoare 5: 9 apariții
#     Valoare 2: 2 apariții
#     Valoare 3: 2 apariții
#     Valoare 1: 1 apariții
#   Clasa 8:
#     Valoare 4: 92 apariții
#     Valoare 5: 76 apariții
#     Valoare 3: 35 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 4 apariții
#   Clasa 11:
#     Valoare 5: 14 apariții
#     Valoare 4: 9 apariții
#     Valoare 1: 3 apariții
#     Valoare 3: 2 apariții
#   Clasa 9:
#     Valoare 5: 42 apariții
#     Valoare 4: 26 apariții
#     Valoare 3: 4 apariții
#     Valoare 2: 3 apariții
#     Valoare 1: 1 apariții
#   Clasa 14:
#     Valoare 5: 14 apariții
#     Valoare 4: 10 apariții
#     Valoare 3: 1 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Vigilant
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 1212 apariții
#   Valoare 5: 1044 apariții
#   Valoare 3: 477 apariții
#   Valoare 2: 275 apariții
#   Valoare 1: 131 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 82 apariții
#     Valoare 5: 46 apariții
#     Valoare 3: 37 apariții
#     Valoare 2: 18 apariții
#     Valoare 1: 9 apariții
#   Clasa 5:
#     Valoare 4: 403 apariții
#     Valoare 5: 381 apariții
#     Valoare 3: 139 apariții
#     Valoare 2: 61 apariții
#     Valoare 1: 36 apariții
#   Clasa 13:
#     Valoare 4: 183 apariții
#     Valoare 5: 163 apariții
#     Valoare 3: 73 apariții
#     Valoare 2: 43 apariții
#     Valoare 1: 21 apariții
#   Clasa 6:
#     Valoare 5: 72 apariții
#     Valoare 4: 70 apariții
#     Valoare 3: 33 apariții
#     Valoare 2: 15 apariții
#     Valoare 1: 8 apariții
#   Clasa 1:
#     Valoare 4: 91 apariții
#     Valoare 5: 84 apariții
#     Valoare 3: 34 apariții
#     Valoare 2: 21 apariții
#     Valoare 1: 8 apariții
#   Clasa 7:
#     Valoare 4: 116 apariții
#     Valoare 5: 73 apariții
#     Valoare 3: 43 apariții
#     Valoare 2: 31 apariții
#     Valoare 1: 8 apariții
#   Clasa 10:
#     Valoare 4: 22 apariții
#     Valoare 5: 22 apariții
#     Valoare 3: 9 apariții
#     Valoare 2: 5 apariții
#   Clasa 3:
#     Valoare 4: 63 apariții
#     Valoare 5: 54 apariții
#     Valoare 3: 27 apariții
#     Valoare 2: 16 apariții
#     Valoare 1: 6 apariții
#   Clasa 12:
#     Valoare 4: 50 apariții
#     Valoare 5: 46 apariții
#     Valoare 3: 21 apariții
#     Valoare 2: 13 apariții
#     Valoare 1: 5 apariții
#   Clasa 4:
#     Valoare 4: 14 apariții
#     Valoare 5: 11 apariții
#     Valoare 2: 3 apariții
#     Valoare 3: 2 apariții
#     Valoare 1: 1 apariții
#   Clasa 8:
#     Valoare 4: 77 apariții
#     Valoare 5: 43 apariții
#     Valoare 2: 41 apariții
#     Valoare 3: 35 apariții
#     Valoare 1: 21 apariții
#   Clasa 11:
#     Valoare 5: 13 apariții
#     Valoare 4: 10 apariții
#     Valoare 1: 3 apariții
#     Valoare 3: 2 apariții
#   Clasa 9:
#     Valoare 5: 25 apariții
#     Valoare 4: 23 apariții
#     Valoare 3: 17 apariții
#     Valoare 2: 7 apariții
#     Valoare 1: 4 apariții
#   Clasa 14:
#     Valoare 5: 11 apariții
#     Valoare 4: 8 apariții
#     Valoare 3: 5 apariții
#     Valoare 2: 1 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Perséverant
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 1114 apariții
#   Valoare 5: 1044 apariții
#   Valoare 3: 610 apariții
#   Valoare 2: 255 apariții
#   Valoare 1: 116 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 74 apariții
#     Valoare 5: 61 apariții
#     Valoare 3: 44 apariții
#     Valoare 2: 9 apariții
#     Valoare 1: 4 apariții
#   Clasa 5:
#     Valoare 4: 362 apariții
#     Valoare 5: 352 apariții
#     Valoare 3: 192 apariții
#     Valoare 2: 79 apariții
#     Valoare 1: 35 apariții
#   Clasa 13:
#     Valoare 4: 159 apariții
#     Valoare 5: 158 apariții
#     Valoare 3: 104 apariții
#     Valoare 2: 43 apariții
#     Valoare 1: 19 apariții
#   Clasa 6:
#     Valoare 5: 77 apariții
#     Valoare 4: 70 apariții
#     Valoare 3: 35 apariții
#     Valoare 2: 9 apariții
#     Valoare 1: 7 apariții
#   Clasa 1:
#     Valoare 5: 112 apariții
#     Valoare 4: 89 apariții
#     Valoare 3: 25 apariții
#     Valoare 1: 6 apariții
#     Valoare 2: 6 apariții
#   Clasa 7:
#     Valoare 4: 96 apariții
#     Valoare 5: 66 apariții
#     Valoare 3: 63 apariții
#     Valoare 2: 31 apariții
#     Valoare 1: 15 apariții
#   Clasa 10:
#     Valoare 4: 22 apariții
#     Valoare 3: 18 apariții
#     Valoare 5: 13 apariții
#     Valoare 2: 4 apariții
#     Valoare 1: 1 apariții
#   Clasa 3:
#     Valoare 4: 56 apariții
#     Valoare 5: 53 apariții
#     Valoare 3: 33 apariții
#     Valoare 2: 17 apariții
#     Valoare 1: 7 apariții
#   Clasa 12:
#     Valoare 5: 52 apariții
#     Valoare 4: 41 apariții
#     Valoare 3: 26 apariții
#     Valoare 2: 15 apariții
#     Valoare 1: 1 apariții
#   Clasa 4:
#     Valoare 4: 13 apariții
#     Valoare 5: 8 apariții
#     Valoare 3: 5 apariții
#     Valoare 2: 4 apariții
#     Valoare 1: 1 apariții
#   Clasa 8:
#     Valoare 4: 81 apariții
#     Valoare 3: 50 apariții
#     Valoare 5: 44 apariții
#     Valoare 2: 29 apariții
#     Valoare 1: 13 apariții
#   Clasa 11:
#     Valoare 4: 13 apariții
#     Valoare 5: 10 apariții
#     Valoare 2: 2 apariții
#     Valoare 1: 2 apariții
#     Valoare 3: 1 apariții
#   Clasa 9:
#     Valoare 5: 31 apariții
#     Valoare 4: 27 apariții
#     Valoare 3: 10 apariții
#     Valoare 2: 4 apariții
#     Valoare 1: 4 apariții
#   Clasa 14:
#     Valoare 4: 11 apariții
#     Valoare 5: 7 apariții
#     Valoare 3: 4 apariții
#     Valoare 2: 3 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Affectueux
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 5: 1500 apariții
#   Valoare 4: 992 apariții
#   Valoare 3: 352 apariții
#   Valoare 2: 212 apariții
#   Valoare 1: 83 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 5: 95 apariții
#     Valoare 4: 69 apariții
#     Valoare 3: 15 apariții
#     Valoare 2: 11 apariții
#     Valoare 1: 2 apariții
#   Clasa 5:
#     Valoare 5: 478 apariții
#     Valoare 4: 326 apariții
#     Valoare 3: 122 apariții
#     Valoare 2: 65 apariții
#     Valoare 1: 29 apariții
#   Clasa 13:
#     Valoare 5: 243 apariții
#     Valoare 4: 141 apariții
#     Valoare 3: 50 apariții
#     Valoare 2: 35 apariții
#     Valoare 1: 14 apariții
#   Clasa 6:
#     Valoare 5: 104 apariții
#     Valoare 4: 53 apariții
#     Valoare 3: 27 apariții
#     Valoare 2: 11 apariții
#     Valoare 1: 3 apariții
#   Clasa 1:
#     Valoare 5: 102 apariții
#     Valoare 4: 78 apariții
#     Valoare 3: 30 apariții
#     Valoare 2: 21 apariții
#     Valoare 1: 7 apariții
#   Clasa 7:
#     Valoare 5: 126 apariții
#     Valoare 4: 88 apariții
#     Valoare 3: 32 apariții
#     Valoare 2: 16 apariții
#     Valoare 1: 9 apariții
#   Clasa 10:
#     Valoare 5: 22 apariții
#     Valoare 4: 20 apariții
#     Valoare 2: 8 apariții
#     Valoare 3: 7 apariții
#     Valoare 1: 1 apariții
#   Clasa 3:
#     Valoare 5: 64 apariții
#     Valoare 4: 59 apariții
#     Valoare 3: 22 apariții
#     Valoare 2: 18 apariții
#     Valoare 1: 3 apariții
#   Clasa 12:
#     Valoare 5: 75 apariții
#     Valoare 4: 37 apariții
#     Valoare 3: 10 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 3 apariții
#   Clasa 4:
#     Valoare 5: 16 apariții
#     Valoare 4: 9 apariții
#     Valoare 3: 3 apariții
#     Valoare 2: 2 apariții
#     Valoare 1: 1 apariții
#   Clasa 8:
#     Valoare 5: 104 apariții
#     Valoare 4: 68 apariții
#     Valoare 3: 27 apariții
#     Valoare 2: 12 apariții
#     Valoare 1: 6 apariții
#   Clasa 11:
#     Valoare 5: 15 apariții
#     Valoare 4: 9 apariții
#     Valoare 3: 2 apariții
#     Valoare 1: 2 apariții
#   Clasa 9:
#     Valoare 5: 45 apariții
#     Valoare 4: 24 apariții
#     Valoare 3: 3 apariții
#     Valoare 1: 2 apariții
#     Valoare 2: 2 apariții
#   Clasa 14:
#     Valoare 4: 11 apariții
#     Valoare 5: 11 apariții
#     Valoare 3: 2 apariții
#     Valoare 2: 1 apariții
#     Valoare 1: 1 apariții
# --------------------------------------------------
#
# Atribut: Amical
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 1048 apariții
#   Valoare 5: 733 apariții
#   Valoare 3: 522 apariții
#   Valoare 2: 505 apariții
#   Valoare 1: 331 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 74 apariții
#     Valoare 5: 57 apariții
#     Valoare 3: 29 apariții
#     Valoare 2: 24 apariții
#     Valoare 1: 8 apariții
#   Clasa 5:
#     Valoare 4: 312 apariții
#     Valoare 2: 198 apariții
#     Valoare 5: 186 apariții
#     Valoare 3: 175 apariții
#     Valoare 1: 149 apariții
#   Clasa 13:
#     Valoare 4: 140 apariții
#     Valoare 5: 101 apariții
#     Valoare 2: 97 apariții
#     Valoare 3: 83 apariții
#     Valoare 1: 62 apariții
#   Clasa 6:
#     Valoare 4: 69 apariții
#     Valoare 5: 54 apariții
#     Valoare 3: 36 apariții
#     Valoare 2: 28 apariții
#     Valoare 1: 11 apariții
#   Clasa 1:
#     Valoare 4: 99 apariții
#     Valoare 5: 51 apariții
#     Valoare 3: 46 apariții
#     Valoare 2: 29 apariții
#     Valoare 1: 13 apariții
#   Clasa 7:
#     Valoare 4: 96 apariții
#     Valoare 5: 56 apariții
#     Valoare 3: 46 apariții
#     Valoare 2: 41 apariții
#     Valoare 1: 32 apariții
#   Clasa 10:
#     Valoare 5: 16 apariții
#     Valoare 4: 13 apariții
#     Valoare 3: 12 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 7 apariții
#   Clasa 3:
#     Valoare 4: 63 apariții
#     Valoare 2: 31 apariții
#     Valoare 3: 30 apariții
#     Valoare 5: 29 apariții
#     Valoare 1: 13 apariții
#   Clasa 12:
#     Valoare 4: 49 apariții
#     Valoare 5: 45 apariții
#     Valoare 3: 16 apariții
#     Valoare 2: 15 apariții
#     Valoare 1: 10 apariții
#   Clasa 4:
#     Valoare 4: 11 apariții
#     Valoare 5: 10 apariții
#     Valoare 2: 4 apariții
#     Valoare 1: 3 apariții
#     Valoare 3: 3 apariții
#   Clasa 8:
#     Valoare 4: 79 apariții
#     Valoare 5: 77 apariții
#     Valoare 3: 30 apariții
#     Valoare 2: 22 apariții
#     Valoare 1: 9 apariții
#   Clasa 11:
#     Valoare 4: 9 apariții
#     Valoare 5: 7 apariții
#     Valoare 3: 6 apariții
#     Valoare 1: 5 apariții
#     Valoare 2: 1 apariții
#   Clasa 9:
#     Valoare 5: 40 apariții
#     Valoare 4: 29 apariții
#     Valoare 3: 3 apariții
#     Valoare 1: 3 apariții
#     Valoare 2: 1 apariții
#   Clasa 14:
#     Valoare 3: 7 apariții
#     Valoare 1: 6 apariții
#     Valoare 4: 5 apariții
#     Valoare 5: 4 apariții
#     Valoare 2: 4 apariții
# --------------------------------------------------
#
# Atribut: Solitaire
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 2: 829 apariții
#   Valoare 1: 813 apariții
#   Valoare 4: 680 apariții
#   Valoare 3: 604 apariții
#   Valoare 5: 213 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 65 apariții
#     Valoare 2: 58 apariții
#     Valoare 3: 31 apariții
#     Valoare 4: 30 apariții
#     Valoare 5: 8 apariții
#   Clasa 5:
#     Valoare 4: 276 apariții
#     Valoare 2: 257 apariții
#     Valoare 3: 213 apariții
#     Valoare 1: 187 apariții
#     Valoare 5: 87 apariții
#   Clasa 13:
#     Valoare 2: 131 apariții
#     Valoare 4: 114 apariții
#     Valoare 3: 103 apariții
#     Valoare 1: 94 apariții
#     Valoare 5: 41 apariții
#   Clasa 6:
#     Valoare 1: 75 apariții
#     Valoare 2: 52 apariții
#     Valoare 3: 35 apariții
#     Valoare 4: 29 apariții
#     Valoare 5: 7 apariții
#   Clasa 1:
#     Valoare 1: 81 apariții
#     Valoare 2: 67 apariții
#     Valoare 3: 44 apariții
#     Valoare 4: 36 apariții
#     Valoare 5: 10 apariții
#   Clasa 7:
#     Valoare 2: 67 apariții
#     Valoare 4: 62 apariții
#     Valoare 3: 62 apariții
#     Valoare 1: 57 apariții
#     Valoare 5: 23 apariții
#   Clasa 10:
#     Valoare 2: 16 apariții
#     Valoare 4: 12 apariții
#     Valoare 1: 12 apariții
#     Valoare 5: 10 apariții
#     Valoare 3: 8 apariții
#   Clasa 3:
#     Valoare 4: 50 apariții
#     Valoare 2: 46 apariții
#     Valoare 1: 34 apariții
#     Valoare 3: 29 apariții
#     Valoare 5: 7 apariții
#   Clasa 12:
#     Valoare 1: 42 apariții
#     Valoare 2: 40 apariții
#     Valoare 4: 23 apariții
#     Valoare 3: 22 apariții
#     Valoare 5: 8 apariții
#   Clasa 4:
#     Valoare 2: 12 apariții
#     Valoare 4: 8 apariții
#     Valoare 3: 6 apariții
#     Valoare 1: 4 apariții
#     Valoare 5: 1 apariții
#   Clasa 8:
#     Valoare 1: 98 apariții
#     Valoare 2: 57 apariții
#     Valoare 3: 29 apariții
#     Valoare 4: 27 apariții
#     Valoare 5: 6 apariții
#   Clasa 11:
#     Valoare 3: 9 apariții
#     Valoare 1: 7 apariții
#     Valoare 2: 6 apariții
#     Valoare 4: 5 apariții
#     Valoare 5: 1 apariții
#   Clasa 9:
#     Valoare 1: 49 apariții
#     Valoare 2: 11 apariții
#     Valoare 3: 10 apariții
#     Valoare 5: 4 apariții
#     Valoare 4: 2 apariții
#   Clasa 14:
#     Valoare 2: 9 apariții
#     Valoare 1: 8 apariții
#     Valoare 4: 6 apariții
#     Valoare 3: 3 apariții
# --------------------------------------------------
#
# Atribut: Brutal
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1745 apariții
#   Valoare 2: 604 apariții
#   Valoare 3: 436 apariții
#   Valoare 4: 273 apariții
#   Valoare 5: 81 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 123 apariții
#     Valoare 2: 35 apariții
#     Valoare 3: 19 apariții
#     Valoare 4: 12 apariții
#     Valoare 5: 3 apariții
#   Clasa 5:
#     Valoare 1: 537 apariții
#     Valoare 2: 191 apariții
#     Valoare 3: 150 apariții
#     Valoare 4: 102 apariții
#     Valoare 5: 40 apariții
#   Clasa 13:
#     Valoare 1: 241 apariții
#     Valoare 2: 106 apariții
#     Valoare 3: 74 apariții
#     Valoare 4: 52 apariții
#     Valoare 5: 10 apariții
#   Clasa 6:
#     Valoare 1: 102 apariții
#     Valoare 2: 42 apariții
#     Valoare 3: 31 apariții
#     Valoare 4: 17 apariții
#     Valoare 5: 6 apariții
#   Clasa 1:
#     Valoare 1: 87 apariții
#     Valoare 3: 56 apariții
#     Valoare 2: 54 apariții
#     Valoare 4: 37 apariții
#     Valoare 5: 4 apariții
#   Clasa 7:
#     Valoare 1: 173 apariții
#     Valoare 2: 52 apariții
#     Valoare 3: 27 apariții
#     Valoare 4: 13 apariții
#     Valoare 5: 6 apariții
#   Clasa 10:
#     Valoare 1: 37 apariții
#     Valoare 3: 14 apariții
#     Valoare 2: 5 apariții
#     Valoare 4: 2 apariții
#   Clasa 3:
#     Valoare 1: 106 apariții
#     Valoare 2: 31 apariții
#     Valoare 3: 17 apariții
#     Valoare 4: 8 apariții
#     Valoare 5: 4 apariții
#   Clasa 12:
#     Valoare 1: 83 apariții
#     Valoare 2: 25 apariții
#     Valoare 3: 18 apariții
#     Valoare 4: 9 apariții
#   Clasa 4:
#     Valoare 1: 17 apariții
#     Valoare 2: 8 apariții
#     Valoare 3: 4 apariții
#     Valoare 4: 2 apariții
#   Clasa 8:
#     Valoare 1: 168 apariții
#     Valoare 2: 31 apariții
#     Valoare 3: 14 apariții
#     Valoare 5: 2 apariții
#     Valoare 4: 2 apariții
#   Clasa 11:
#     Valoare 1: 18 apariții
#     Valoare 2: 4 apariții
#     Valoare 5: 2 apariții
#     Valoare 4: 2 apariții
#     Valoare 3: 2 apariții
#   Clasa 9:
#     Valoare 1: 45 apariții
#     Valoare 2: 12 apariții
#     Valoare 3: 8 apariții
#     Valoare 4: 7 apariții
#     Valoare 5: 4 apariții
#   Clasa 14:
#     Valoare 4: 8 apariții
#     Valoare 1: 8 apariții
#     Valoare 2: 8 apariții
#     Valoare 3: 2 apariții
# --------------------------------------------------
#
# Atribut: Dominant
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1000 apariții
#   Valoare 3: 720 apariții
#   Valoare 4: 587 apariții
#   Valoare 2: 570 apariții
#   Valoare 5: 262 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 68 apariții
#     Valoare 3: 39 apariții
#     Valoare 2: 37 apariții
#     Valoare 4: 36 apariții
#     Valoare 5: 12 apariții
#   Clasa 5:
#     Valoare 1: 302 apariții
#     Valoare 3: 254 apariții
#     Valoare 4: 195 apariții
#     Valoare 2: 176 apariții
#     Valoare 5: 93 apariții
#   Clasa 13:
#     Valoare 1: 158 apariții
#     Valoare 4: 107 apariții
#     Valoare 3: 97 apariții
#     Valoare 2: 79 apariții
#     Valoare 5: 42 apariții
#   Clasa 6:
#     Valoare 1: 57 apariții
#     Valoare 2: 43 apariții
#     Valoare 3: 41 apariții
#     Valoare 4: 38 apariții
#     Valoare 5: 19 apariții
#   Clasa 1:
#     Valoare 4: 67 apariții
#     Valoare 3: 61 apariții
#     Valoare 2: 45 apariții
#     Valoare 1: 40 apariții
#     Valoare 5: 25 apariții
#   Clasa 7:
#     Valoare 1: 107 apariții
#     Valoare 3: 57 apariții
#     Valoare 2: 53 apariții
#     Valoare 4: 34 apariții
#     Valoare 5: 20 apariții
#   Clasa 10:
#     Valoare 1: 17 apariții
#     Valoare 3: 14 apariții
#     Valoare 2: 11 apariții
#     Valoare 4: 8 apariții
#     Valoare 5: 8 apariții
#   Clasa 3:
#     Valoare 1: 67 apariții
#     Valoare 3: 37 apariții
#     Valoare 2: 32 apariții
#     Valoare 4: 20 apariții
#     Valoare 5: 10 apariții
#   Clasa 12:
#     Valoare 1: 46 apariții
#     Valoare 3: 32 apariții
#     Valoare 4: 22 apariții
#     Valoare 2: 22 apariții
#     Valoare 5: 13 apariții
#   Clasa 4:
#     Valoare 4: 11 apariții
#     Valoare 3: 8 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 5 apariții
#     Valoare 5: 1 apariții
#   Clasa 8:
#     Valoare 1: 94 apariții
#     Valoare 2: 44 apariții
#     Valoare 3: 44 apariții
#     Valoare 4: 27 apariții
#     Valoare 5: 8 apariții
#   Clasa 11:
#     Valoare 1: 8 apariții
#     Valoare 4: 7 apariții
#     Valoare 3: 7 apariții
#     Valoare 2: 5 apariții
#     Valoare 5: 1 apariții
#   Clasa 9:
#     Valoare 1: 29 apariții
#     Valoare 3: 22 apariții
#     Valoare 4: 10 apariții
#     Valoare 2: 10 apariții
#     Valoare 5: 5 apariții
#   Clasa 14:
#     Valoare 2: 7 apariții
#     Valoare 3: 7 apariții
#     Valoare 4: 5 apariții
#     Valoare 5: 5 apariții
#     Valoare 1: 2 apariții
# --------------------------------------------------
#
# Atribut: Agressif
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1165 apariții
#   Valoare 3: 865 apariții
#   Valoare 2: 570 apariții
#   Valoare 4: 368 apariții
#   Valoare 5: 171 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 86 apariții
#     Valoare 3: 44 apariții
#     Valoare 2: 36 apariții
#     Valoare 4: 23 apariții
#     Valoare 5: 3 apariții
#   Clasa 5:
#     Valoare 1: 318 apariții
#     Valoare 3: 296 apariții
#     Valoare 2: 194 apariții
#     Valoare 4: 134 apariții
#     Valoare 5: 78 apariții
#   Clasa 13:
#     Valoare 3: 146 apariții
#     Valoare 1: 139 apariții
#     Valoare 2: 90 apariții
#     Valoare 4: 73 apariții
#     Valoare 5: 35 apariții
#   Clasa 6:
#     Valoare 1: 105 apariții
#     Valoare 2: 42 apariții
#     Valoare 3: 32 apariții
#     Valoare 4: 16 apariții
#     Valoare 5: 3 apariții
#   Clasa 1:
#     Valoare 1: 79 apariții
#     Valoare 3: 69 apariții
#     Valoare 2: 47 apariții
#     Valoare 4: 31 apariții
#     Valoare 5: 12 apariții
#   Clasa 7:
#     Valoare 1: 112 apariții
#     Valoare 3: 73 apariții
#     Valoare 2: 47 apariții
#     Valoare 4: 25 apariții
#     Valoare 5: 14 apariții
#   Clasa 10:
#     Valoare 1: 22 apariții
#     Valoare 3: 12 apariții
#     Valoare 4: 11 apariții
#     Valoare 2: 8 apariții
#     Valoare 5: 5 apariții
#   Clasa 3:
#     Valoare 1: 72 apariții
#     Valoare 3: 46 apariții
#     Valoare 2: 28 apariții
#     Valoare 4: 15 apariții
#     Valoare 5: 5 apariții
#   Clasa 12:
#     Valoare 1: 62 apariții
#     Valoare 3: 33 apariții
#     Valoare 2: 20 apariții
#     Valoare 4: 16 apariții
#     Valoare 5: 4 apariții
#   Clasa 4:
#     Valoare 3: 11 apariții
#     Valoare 1: 8 apariții
#     Valoare 2: 7 apariții
#     Valoare 4: 4 apariții
#     Valoare 5: 1 apariții
#   Clasa 8:
#     Valoare 1: 106 apariții
#     Valoare 3: 66 apariții
#     Valoare 2: 29 apariții
#     Valoare 4: 12 apariții
#     Valoare 5: 4 apariții
#   Clasa 11:
#     Valoare 1: 9 apariții
#     Valoare 3: 9 apariții
#     Valoare 2: 6 apariții
#     Valoare 5: 2 apariții
#     Valoare 4: 2 apariții
#   Clasa 9:
#     Valoare 1: 42 apariții
#     Valoare 3: 19 apariții
#     Valoare 2: 9 apariții
#     Valoare 4: 4 apariții
#     Valoare 5: 2 apariții
#   Clasa 14:
#     Valoare 3: 9 apariții
#     Valoare 2: 7 apariții
#     Valoare 1: 5 apariții
#     Valoare 5: 3 apariții
#     Valoare 4: 2 apariții
# --------------------------------------------------
#
# Atribut: Impulsif
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 1: 1008 apariții
#   Valoare 3: 687 apariții
#   Valoare 2: 674 apariții
#   Valoare 4: 585 apariții
#   Valoare 5: 185 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 1: 67 apariții
#     Valoare 3: 51 apariții
#     Valoare 2: 48 apariții
#     Valoare 4: 23 apariții
#     Valoare 5: 3 apariții
#   Clasa 5:
#     Valoare 1: 280 apariții
#     Valoare 3: 244 apariții
#     Valoare 2: 212 apariții
#     Valoare 4: 210 apariții
#     Valoare 5: 74 apariții
#   Clasa 13:
#     Valoare 1: 140 apariții
#     Valoare 3: 107 apariții
#     Valoare 2: 102 apariții
#     Valoare 4: 96 apariții
#     Valoare 5: 38 apariții
#   Clasa 6:
#     Valoare 1: 75 apariții
#     Valoare 2: 42 apariții
#     Valoare 3: 39 apariții
#     Valoare 4: 37 apariții
#     Valoare 5: 5 apariții
#   Clasa 1:
#     Valoare 4: 74 apariții
#     Valoare 1: 50 apariții
#     Valoare 3: 45 apariții
#     Valoare 2: 45 apariții
#     Valoare 5: 24 apariții
#   Clasa 7:
#     Valoare 1: 117 apariții
#     Valoare 3: 56 apariții
#     Valoare 2: 52 apariții
#     Valoare 4: 35 apariții
#     Valoare 5: 11 apariții
#   Clasa 10:
#     Valoare 3: 18 apariții
#     Valoare 1: 16 apariții
#     Valoare 4: 13 apariții
#     Valoare 2: 9 apariții
#     Valoare 5: 2 apariții
#   Clasa 3:
#     Valoare 1: 76 apariții
#     Valoare 2: 37 apariții
#     Valoare 3: 28 apariții
#     Valoare 4: 20 apariții
#     Valoare 5: 5 apariții
#   Clasa 12:
#     Valoare 1: 38 apariții
#     Valoare 2: 36 apariții
#     Valoare 3: 29 apariții
#     Valoare 4: 23 apariții
#     Valoare 5: 9 apariții
#   Clasa 4:
#     Valoare 2: 11 apariții
#     Valoare 3: 8 apariții
#     Valoare 1: 7 apariții
#     Valoare 4: 5 apariții
#   Clasa 8:
#     Valoare 1: 97 apariții
#     Valoare 2: 53 apariții
#     Valoare 3: 33 apariții
#     Valoare 4: 28 apariții
#     Valoare 5: 6 apariții
#   Clasa 11:
#     Valoare 1: 9 apariții
#     Valoare 2: 6 apariții
#     Valoare 3: 6 apariții
#     Valoare 4: 6 apariții
#     Valoare 5: 1 apariții
#   Clasa 9:
#     Valoare 1: 31 apariții
#     Valoare 3: 16 apariții
#     Valoare 2: 15 apariții
#     Valoare 4: 9 apariții
#     Valoare 5: 5 apariții
#   Clasa 14:
#     Valoare 3: 7 apariții
#     Valoare 4: 6 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 5 apariții
#     Valoare 5: 2 apariții
# --------------------------------------------------
#
# Atribut: Prévisible
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 1275 apariții
#   Valoare 3: 785 apariții
#   Valoare 5: 428 apariții
#   Valoare 2: 374 apariții
#   Valoare 1: 277 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 4: 76 apariții
#     Valoare 3: 54 apariții
#     Valoare 5: 33 apariții
#     Valoare 2: 16 apariții
#     Valoare 1: 13 apariții
#   Clasa 5:
#     Valoare 4: 390 apariții
#     Valoare 3: 260 apariții
#     Valoare 5: 141 apariții
#     Valoare 2: 128 apariții
#     Valoare 1: 101 apariții
#   Clasa 13:
#     Valoare 4: 195 apariții
#     Valoare 3: 111 apariții
#     Valoare 2: 72 apariții
#     Valoare 5: 63 apariții
#     Valoare 1: 42 apariții
#   Clasa 6:
#     Valoare 4: 76 apariții
#     Valoare 3: 55 apariții
#     Valoare 2: 30 apariții
#     Valoare 5: 25 apariții
#     Valoare 1: 12 apariții
#   Clasa 1:
#     Valoare 4: 109 apariții
#     Valoare 3: 65 apariții
#     Valoare 2: 29 apariții
#     Valoare 5: 23 apariții
#     Valoare 1: 12 apariții
#   Clasa 7:
#     Valoare 4: 103 apariții
#     Valoare 3: 71 apariții
#     Valoare 5: 35 apariții
#     Valoare 2: 34 apariții
#     Valoare 1: 28 apariții
#   Clasa 10:
#     Valoare 3: 22 apariții
#     Valoare 4: 22 apariții
#     Valoare 5: 7 apariții
#     Valoare 1: 5 apariții
#     Valoare 2: 2 apariții
#   Clasa 3:
#     Valoare 4: 74 apariții
#     Valoare 3: 37 apariții
#     Valoare 5: 23 apariții
#     Valoare 2: 16 apariții
#     Valoare 1: 16 apariții
#   Clasa 12:
#     Valoare 4: 51 apariții
#     Valoare 3: 31 apariții
#     Valoare 5: 23 apariții
#     Valoare 2: 15 apariții
#     Valoare 1: 15 apariții
#   Clasa 4:
#     Valoare 4: 17 apariții
#     Valoare 3: 5 apariții
#     Valoare 2: 5 apariții
#     Valoare 5: 2 apariții
#     Valoare 1: 2 apariții
#   Clasa 8:
#     Valoare 4: 105 apariții
#     Valoare 3: 47 apariții
#     Valoare 5: 37 apariții
#     Valoare 2: 17 apariții
#     Valoare 1: 11 apariții
#   Clasa 11:
#     Valoare 4: 12 apariții
#     Valoare 3: 8 apariții
#     Valoare 5: 4 apariții
#     Valoare 1: 3 apariții
#     Valoare 2: 1 apariții
#   Clasa 9:
#     Valoare 4: 35 apariții
#     Valoare 3: 14 apariții
#     Valoare 5: 11 apariții
#     Valoare 1: 10 apariții
#     Valoare 2: 6 apariții
#   Clasa 14:
#     Valoare 4: 10 apariții
#     Valoare 1: 7 apariții
#     Valoare 3: 5 apariții
#     Valoare 2: 3 apariții
#     Valoare 5: 1 apariții
# --------------------------------------------------
#
# Atribut: Distrait
# Număr total de valori distincte: 5
# Frecvența valorilor la nivel total:
#   Valoare 4: 894 apariții
#   Valoare 3: 890 apariții
#   Valoare 2: 558 apariții
#   Valoare 1: 430 apariții
#   Valoare 5: 367 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 3: 63 apariții
#     Valoare 4: 48 apariții
#     Valoare 2: 33 apariții
#     Valoare 1: 25 apariții
#     Valoare 5: 23 apariții
#   Clasa 5:
#     Valoare 3: 292 apariții
#     Valoare 4: 272 apariții
#     Valoare 2: 180 apariții
#     Valoare 1: 166 apariții
#     Valoare 5: 110 apariții
#   Clasa 13:
#     Valoare 3: 135 apariții
#     Valoare 4: 124 apariții
#     Valoare 2: 100 apariții
#     Valoare 5: 64 apariții
#     Valoare 1: 60 apariții
#   Clasa 6:
#     Valoare 4: 60 apariții
#     Valoare 3: 54 apariții
#     Valoare 2: 33 apariții
#     Valoare 5: 29 apariții
#     Valoare 1: 22 apariții
#   Clasa 1:
#     Valoare 4: 85 apariții
#     Valoare 3: 55 apariții
#     Valoare 2: 35 apariții
#     Valoare 5: 33 apariții
#     Valoare 1: 30 apariții
#   Clasa 7:
#     Valoare 4: 85 apariții
#     Valoare 3: 80 apariții
#     Valoare 2: 44 apariții
#     Valoare 1: 34 apariții
#     Valoare 5: 28 apariții
#   Clasa 10:
#     Valoare 3: 18 apariții
#     Valoare 2: 14 apariții
#     Valoare 4: 13 apariții
#     Valoare 1: 8 apariții
#     Valoare 5: 5 apariții
#   Clasa 3:
#     Valoare 4: 53 apariții
#     Valoare 3: 41 apariții
#     Valoare 2: 31 apariții
#     Valoare 1: 26 apariții
#     Valoare 5: 15 apariții
#   Clasa 12:
#     Valoare 4: 41 apariții
#     Valoare 3: 33 apariții
#     Valoare 2: 22 apariții
#     Valoare 1: 20 apariții
#     Valoare 5: 19 apariții
#   Clasa 4:
#     Valoare 2: 11 apariții
#     Valoare 4: 10 apariții
#     Valoare 3: 7 apariții
#     Valoare 1: 3 apariții
#   Clasa 8:
#     Valoare 3: 71 apariții
#     Valoare 4: 67 apariții
#     Valoare 2: 32 apariții
#     Valoare 5: 31 apariții
#     Valoare 1: 16 apariții
#   Clasa 11:
#     Valoare 3: 10 apariții
#     Valoare 2: 7 apariții
#     Valoare 1: 5 apariții
#     Valoare 4: 4 apariții
#     Valoare 5: 2 apariții
#   Clasa 9:
#     Valoare 3: 24 apariții
#     Valoare 4: 23 apariții
#     Valoare 1: 11 apariții
#     Valoare 2: 10 apariții
#     Valoare 5: 8 apariții
#   Clasa 14:
#     Valoare 4: 9 apariții
#     Valoare 3: 7 apariții
#     Valoare 2: 6 apariții
#     Valoare 1: 4 apariții
# --------------------------------------------------
#
# Atribut: Abondance
# Număr total de valori distincte: 3
# Frecvența valorilor la nivel total:
#   Valoare 3: 1335 apariții
#   Valoare 2: 1091 apariții
#   Valoare 1: 713 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 2: 79 apariții
#     Valoare 3: 73 apariții
#     Valoare 1: 40 apariții
#   Clasa 5:
#     Valoare 3: 507 apariții
#     Valoare 2: 300 apariții
#     Valoare 1: 213 apariții
#   Clasa 13:
#     Valoare 3: 240 apariții
#     Valoare 2: 144 apariții
#     Valoare 1: 99 apariții
#   Clasa 6:
#     Valoare 2: 80 apariții
#     Valoare 3: 75 apariții
#     Valoare 1: 43 apariții
#   Clasa 1:
#     Valoare 2: 99 apariții
#     Valoare 3: 79 apariții
#     Valoare 1: 60 apariții
#   Clasa 7:
#     Valoare 3: 107 apariții
#     Valoare 2: 102 apariții
#     Valoare 1: 62 apariții
#   Clasa 10:
#     Valoare 2: 26 apariții
#     Valoare 3: 21 apariții
#     Valoare 1: 11 apariții
#   Clasa 3:
#     Valoare 2: 71 apariții
#     Valoare 3: 55 apariții
#     Valoare 1: 40 apariții
#   Clasa 12:
#     Valoare 2: 53 apariții
#     Valoare 3: 48 apariții
#     Valoare 1: 34 apariții
#   Clasa 4:
#     Valoare 3: 15 apariții
#     Valoare 2: 10 apariții
#     Valoare 1: 6 apariții
#   Clasa 8:
#     Valoare 2: 82 apariții
#     Valoare 1: 77 apariții
#     Valoare 3: 58 apariții
#   Clasa 11:
#     Valoare 3: 12 apariții
#     Valoare 2: 12 apariții
#     Valoare 1: 4 apariții
#   Clasa 9:
#     Valoare 3: 33 apariții
#     Valoare 2: 24 apariții
#     Valoare 1: 19 apariții
#   Clasa 14:
#     Valoare 3: 12 apariții
#     Valoare 2: 9 apariții
#     Valoare 1: 5 apariții
# --------------------------------------------------
#
# Atribut: PredOiseau
# Număr total de valori distincte: 4
# Frecvența valorilor la nivel total:
#   Valoare 2: 2470 apariții
#   Valoare 1: 496 apariții
#   Valoare 3: 116 apariții
#   Valoare 4: 57 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 2: 164 apariții
#     Valoare 1: 21 apariții
#     Valoare 3: 4 apariții
#     Valoare 4: 3 apariții
#   Clasa 5:
#     Valoare 2: 716 apariții
#     Valoare 1: 217 apariții
#     Valoare 3: 60 apariții
#     Valoare 4: 27 apariții
#   Clasa 13:
#     Valoare 2: 344 apariții
#     Valoare 1: 102 apariții
#     Valoare 3: 27 apariții
#     Valoare 4: 10 apariții
#   Clasa 6:
#     Valoare 2: 173 apariții
#     Valoare 1: 20 apariții
#     Valoare 3: 3 apariții
#     Valoare 4: 2 apariții
#   Clasa 1:
#     Valoare 2: 212 apariții
#     Valoare 1: 23 apariții
#     Valoare 3: 2 apariții
#     Valoare 4: 1 apariții
#   Clasa 7:
#     Valoare 2: 227 apariții
#     Valoare 1: 33 apariții
#     Valoare 3: 6 apariții
#     Valoare 4: 5 apariții
#   Clasa 10:
#     Valoare 2: 41 apariții
#     Valoare 1: 14 apariții
#     Valoare 3: 3 apariții
#   Clasa 3:
#     Valoare 2: 145 apariții
#     Valoare 1: 17 apariții
#     Valoare 4: 2 apariții
#     Valoare 3: 2 apariții
#   Clasa 12:
#     Valoare 2: 108 apariții
#     Valoare 1: 21 apariții
#     Valoare 4: 4 apariții
#     Valoare 3: 2 apariții
#   Clasa 4:
#     Valoare 2: 21 apariții
#     Valoare 1: 5 apariții
#     Valoare 3: 3 apariții
#     Valoare 4: 2 apariții
#   Clasa 8:
#     Valoare 2: 206 apariții
#     Valoare 1: 11 apariții
#   Clasa 11:
#     Valoare 2: 20 apariții
#     Valoare 1: 5 apariții
#     Valoare 3: 2 apariții
#     Valoare 4: 1 apariții
#   Clasa 9:
#     Valoare 2: 73 apariții
#     Valoare 1: 2 apariții
#     Valoare 3: 1 apariții
#   Clasa 14:
#     Valoare 2: 20 apariții
#     Valoare 1: 5 apariții
#     Valoare 3: 1 apariții
# --------------------------------------------------
#
# Atribut: PredMamm
# Număr total de valori distincte: 4
# Frecvența valorilor la nivel total:
#   Valoare 2: 2355 apariții
#   Valoare 1: 404 apariții
#   Valoare 4: 196 apariții
#   Valoare 3: 184 apariții
#
# Frecvența valorilor pe clase:
#   Clasa 2:
#     Valoare 2: 160 apariții
#     Valoare 1: 20 apariții
#     Valoare 4: 7 apariții
#     Valoare 3: 5 apariții
#   Clasa 5:
#     Valoare 2: 662 apariții
#     Valoare 1: 166 apariții
#     Valoare 4: 100 apariții
#     Valoare 3: 92 apariții
#   Clasa 13:
#     Valoare 2: 320 apariții
#     Valoare 1: 78 apariții
#     Valoare 4: 46 apariții
#     Valoare 3: 39 apariții
#   Clasa 6:
#     Valoare 2: 164 apariții
#     Valoare 1: 21 apariții
#     Valoare 3: 8 apariții
#     Valoare 4: 5 apariții
#   Clasa 1:
#     Valoare 2: 205 apariții
#     Valoare 1: 18 apariții
#     Valoare 3: 8 apariții
#     Valoare 4: 7 apariții
#   Clasa 7:
#     Valoare 2: 213 apariții
#     Valoare 1: 34 apariții
#     Valoare 3: 17 apariții
#     Valoare 4: 7 apariții
#   Clasa 10:
#     Valoare 2: 43 apariții
#     Valoare 1: 9 apariții
#     Valoare 4: 4 apariții
#     Valoare 3: 2 apariții
#   Clasa 3:
#     Valoare 2: 139 apariții
#     Valoare 1: 19 apariții
#     Valoare 4: 7 apariții
#     Valoare 3: 1 apariții
#   Clasa 12:
#     Valoare 2: 110 apariții
#     Valoare 1: 13 apariții
#     Valoare 4: 7 apariții
#     Valoare 3: 5 apariții
#   Clasa 4:
#     Valoare 2: 22 apariții
#     Valoare 4: 4 apariții
#     Valoare 3: 3 apariții
#     Valoare 1: 2 apariții
#   Clasa 8:
#     Valoare 2: 200 apariții
#     Valoare 1: 13 apariții
#     Valoare 3: 4 apariții
#   Clasa 11:
#     Valoare 2: 19 apariții
#     Valoare 1: 7 apariții
#     Valoare 4: 2 apariții
#   Clasa 9:
#     Valoare 2: 75 apariții
#     Valoare 1: 1 apariții
#   Clasa 14:
#     Valoare 2: 23 apariții
#     Valoare 1: 3 apariții
# --------------------------------------------------
# {'Sexe': {'total_valori_distincte': 2, 'frecventa_valori_total': {2: 1655, 1: 1484}, 'frecventa_pe_clase': {np.int64(2): {1: 99, 2: 93}, np.int64(5): {2: 523, 1: 497}, np.int64(13): {2: 251, 1: 232}, np.int64(6): {2: 127, 1: 71}, np.int64(1): {2: 123, 1: 115}, np.int64(7): {2: 158, 1: 113}, np.int64(10): {2: 30, 1: 28}, np.int64(3): {2: 91, 1: 75}, np.int64(12): {1: 70, 2: 65}, np.int64(4): {2: 19, 1: 12}, np.int64(8): {1: 110, 2: 107}, np.int64(11): {1: 14, 2: 14}, np.int64(9): {2: 38, 1: 38}, np.int64(14): {2: 16, 1: 10}}}, 'Age': {'total_valori_distincte': 4, 'frecventa_valori_total': {3: 1559, 2: 617, 1: 607, 4: 356}, 'frecventa_pe_clase': {np.int64(2): {3: 97, 1: 46, 2: 39, 4: 10}, np.int64(5): {3: 518, 1: 171, 4: 171, 2: 160}, np.int64(13): {3: 253, 4: 81, 1: 75, 2: 74}, np.int64(6): {3: 96, 2: 56, 1: 39, 4: 7}, np.int64(1): {3: 106, 2: 69, 1: 57, 4: 6}, np.int64(7): {3: 138, 2: 58, 1: 44, 4: 31}, np.int64(10): {3: 27, 4: 13, 2: 10, 1: 8}, np.int64(3): {3: 78, 2: 41, 1: 40, 4: 7}, np.int64(12): {3: 80, 1: 27, 2: 21, 4: 7}, np.int64(4): {3: 19, 4: 6, 1: 3, 2: 3}, np.int64(8): {3: 98, 1: 65, 2: 48, 4: 6}, np.int64(11): {3: 9, 4: 7, 1: 7, 2: 5}, np.int64(9): {2: 27, 3: 26, 1: 19, 4: 4}, np.int64(14): {3: 14, 2: 6, 1: 6}}}, 'Nombre': {'total_valori_distincte': 6, 'frecventa_valori_total': {1: 1280, 2: 972, 3: 364, 6: 225, 4: 202, 5: 96}, 'frecventa_pe_clase': {np.int64(2): {1: 84, 2: 60, 3: 24, 4: 11, 6: 8, 5: 5}, np.int64(5): {1: 396, 2: 316, 3: 132, 4: 80, 6: 66, 5: 30}, np.int64(13): {1: 178, 2: 175, 3: 56, 4: 29, 6: 28, 5: 17}, np.int64(6): {2: 57, 1: 47, 3: 38, 6: 31, 4: 15, 5: 10}, np.int64(1): {1: 111, 2: 68, 3: 23, 6: 14, 4: 11, 5: 11}, np.int64(7): {1: 131, 2: 89, 4: 17, 6: 15, 3: 15, 5: 4}, np.int64(10): {1: 22, 2: 19, 4: 6, 6: 6, 3: 3, 5: 2}, np.int64(3): {1: 89, 2: 46, 6: 12, 3: 11, 4: 5, 5: 3}, np.int64(12): {1: 51, 2: 29, 3: 27, 6: 14, 4: 11, 5: 3}, np.int64(4): {1: 12, 2: 12, 6: 4, 4: 2, 3: 1}, np.int64(8): {1: 104, 2: 72, 3: 18, 6: 12, 4: 6, 5: 5}, np.int64(11): {1: 11, 2: 7, 3: 4, 6: 2, 5: 2, 4: 2}, np.int64(9): {1: 32, 2: 20, 6: 10, 3: 7, 4: 4, 5: 3}, np.int64(14): {1: 12, 3: 5, 6: 3, 4: 3, 2: 2, 5: 1}}}, 'Logement': {'total_valori_distincte': 4, 'frecventa_valori_total': {4: 998, 3: 988, 2: 784, 1: 369}, 'frecventa_pe_clase': {np.int64(2): {4: 67, 3: 59, 2: 48, 1: 18}, np.int64(5): {3: 333, 4: 329, 2: 241, 1: 117}, np.int64(13): {4: 159, 3: 152, 2: 108, 1: 64}, np.int64(6): {4: 77, 3: 65, 2: 40, 1: 16}, np.int64(1): {2: 76, 3: 66, 4: 64, 1: 32}, np.int64(7): {3: 93, 4: 92, 2: 62, 1: 24}, np.int64(10): {3: 20, 2: 18, 4: 14, 1: 6}, np.int64(3): {3: 53, 2: 48, 4: 47, 1: 18}, np.int64(12): {4: 40, 3: 39, 2: 38, 1: 18}, np.int64(4): {4: 12, 3: 8, 2: 6, 1: 5}, np.int64(8): {4: 63, 3: 62, 2: 62, 1: 30}, np.int64(11): {3: 9, 1: 7, 2: 7, 4: 5}, np.int64(9): {3: 22, 4: 21, 2: 20, 1: 13}, np.int64(14): {2: 10, 4: 8, 3: 7, 1: 1}}}, 'Zone': {'total_valori_distincte': 3, 'frecventa_valori_total': {3: 1224, 1: 1099, 2: 816}, 'frecventa_pe_clase': {np.int64(2): {3: 81, 1: 57, 2: 54}, np.int64(5): {3: 410, 1: 341, 2: 269}, np.int64(13): {3: 196, 1: 166, 2: 121}, np.int64(6): {3: 79, 1: 62, 2: 57}, np.int64(1): {3: 89, 1: 87, 2: 62}, np.int64(7): {3: 105, 1: 88, 2: 78}, np.int64(10): {1: 28, 3: 17, 2: 13}, np.int64(3): {1: 68, 3: 54, 2: 44}, np.int64(12): {3: 61, 1: 39, 2: 35}, np.int64(4): {3: 13, 1: 11, 2: 7}, np.int64(8): {1: 94, 3: 75, 2: 48}, np.int64(11): {1: 17, 2: 6, 3: 5}, np.int64(9): {1: 32, 3: 27, 2: 17}, np.int64(14): {3: 12, 1: 9, 2: 5}}}, 'Ext': {'total_valori_distincte': 4, 'frecventa_valori_total': {2: 2107, 1: 624, 3: 374, 4: 34}, 'frecventa_pe_clase': {np.int64(2): {2: 132, 1: 55, 3: 5}, np.int64(5): {2: 623, 3: 210, 1: 167, 4: 20}, np.int64(13): {2: 317, 1: 82, 3: 76, 4: 8}, np.int64(6): {2: 153, 1: 34, 3: 10, 4: 1}, np.int64(1): {2: 166, 1: 59, 3: 13}, np.int64(7): {2: 188, 1: 58, 3: 24, 4: 1}, np.int64(10): {2: 42, 1: 9, 3: 6, 4: 1}, np.int64(3): {2: 109, 1: 46, 3: 10, 4: 1}, np.int64(12): {2: 94, 1: 2 ...
